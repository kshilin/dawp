# %%
# Данные тут
# https://data.seattle.gov/Transportation/Fremont-Bridge-Bicycle-Counter/65db-xm6k
# 


import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import datetime

display(pd.__version__)
display(matplotlib.__version__)
display(sns.__version__)
# Out:
# '2.2.1'
# '3.8.4'
# '0.13.2'

# %%
temp=pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv')
display(temp.head(3))
display(temp.tail(3))
temp.info()
# Out:
#                      Date  Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# 0  11/01/2019 12:00:00 AM                  12.0                           7.0
# 1  11/01/2019 01:00:00 AM                   7.0                           0.0
# 2  11/01/2019 02:00:00 AM                   1.0                           0.0
#
#    Fremont Bridge West Sidewalk
# 0                           5.0
# 1                           7.0
# 2                           1.0
#                           Date  Fremont Bridge Total  \
# 141419  04/30/2021 09:00:00 PM                  34.0
# 141420  04/30/2021 10:00:00 PM                  34.0
# 141421  04/30/2021 11:00:00 PM                  36.0
#
#         Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 141419                          14.0                          20.0
# 141420                          13.0                          21.0
# 141421                          12.0                          24.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141422 entries, 0 to 141421
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          141422 non-null  object
#  1   Fremont Bridge Total          141400 non-null  float64
#  2   Fremont Bridge East Sidewalk  141400 non-null  float64
#  3   Fremont Bridge West Sidewalk  141400 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 4.3+ MB

# %%
df = pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv',
                 index_col='Date', 
                 parse_dates = True).sort_index()
#### нельзя просто удалить дубликаты, произойдет удаление одинакового содержания вместе с различными индексами!!!
#### нужно удалять ИМЕННО одинаковае индексы
display(df[df.index.duplicated(keep='last')])


df = df[~df.index.duplicated(keep='last')]

######### 2021 ПАНДЕМИЯ
df = df.loc[:'2020']
df
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_48788/2578402280.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv',
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2020-04-30 19:00:00                 156.0                          68.0
# 2020-04-30 20:00:00                  51.0                          30.0
# 2020-04-30 21:00:00                  25.0                          17.0
# 2020-04-30 22:00:00                  15.0                           4.0
# 2020-04-30 23:00:00                  13.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
# ...                                           ...
# 2020-04-30 19:00:00                          88.0
# 2020-04-30 20:00:00                          21.0
# 2020-04-30 21:00:00                           8.0
# 2020-04-30 22:00:00                          11.0
# 2020-04-30 23:00:00                           7.0
#
# [66254 rows x 3 columns]
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
# ...                                   ...                           ...
# 2020-12-31 19:00:00                  27.0                          11.0
# 2020-12-31 20:00:00                  18.0                           9.0
# 2020-12-31 21:00:00                  18.0                           9.0
# 2020-12-31 22:00:00                   9.0                           3.0
# 2020-12-31 23:00:00                   8.0                           3.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
# ...                                           ...
# 2020-12-31 19:00:00                          16.0
# 2020-12-31 20:00:00                           9.0
# 2020-12-31 21:00:00                           9.0
# 2020-12-31 22:00:00                           6.0
# 2020-12-31 23:00:00                           5.0
#
# [72288 rows x 3 columns]

# %%
# 2020 ПАНДЕМИЯ
df = df.loc[:'2019']
df.plot(figsize = (10,3));

# %%
display(df.head(5))
display(df.tail(5))
df.info()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-12-31 19:00:00                  19.0                           8.0
# 2019-12-31 20:00:00                  13.0                           6.0
# 2019-12-31 21:00:00                  15.0                           8.0
# 2019-12-31 22:00:00                  15.0                           5.0
# 2019-12-31 23:00:00                  16.0                           7.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-12-31 19:00:00                          11.0
# 2019-12-31 20:00:00                           7.0
# 2019-12-31 21:00:00                           7.0
# 2019-12-31 22:00:00                          10.0
# 2019-12-31 23:00:00                           9.0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 63504 entries, 2012-10-03 00:00:00 to 2019-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Fremont Bridge Total          63494 non-null  float64
#  1   Fremont Bridge East Sidewalk  63494 non-null  float64
#  2   Fremont Bridge West Sidewalk  63494 non-null  float64
# dtypes: float64(3)
# memory usage: 1.9 MB

# %%
(df['Fremont Bridge East Sidewalk'] + df['Fremont Bridge West Sidewalk'] != df['Fremont Bridge Total']).sum()
# Out:
# 10

# %%
df[df['Fremont Bridge East Sidewalk'] + df['Fremont Bridge West Sidewalk'] != df['Fremont Bridge Total']]
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2013-06-14 09:00:00                   NaN                           NaN
# 2013-06-14 10:00:00                   NaN                           NaN
# 2014-03-09 02:00:00                   NaN                           NaN
# 2015-03-08 02:00:00                   NaN                           NaN
# 2015-04-21 11:00:00                   NaN                           NaN
# 2015-04-21 12:00:00                   NaN                           NaN
# 2016-03-13 02:00:00                   NaN                           NaN
# 2017-03-12 02:00:00                   NaN                           NaN
# 2018-03-11 02:00:00                   NaN                           NaN
# 2019-03-10 02:00:00                   NaN                           NaN
#
#                      Fremont Bridge West Sidewalk
# Date
# 2013-06-14 09:00:00                           NaN
# 2013-06-14 10:00:00                           NaN
# 2014-03-09 02:00:00                           NaN
# 2015-03-08 02:00:00                           NaN
# 2015-04-21 11:00:00                           NaN
# 2015-04-21 12:00:00                           NaN
# 2016-03-13 02:00:00                           NaN
# 2017-03-12 02:00:00                           NaN
# 2018-03-11 02:00:00                           NaN
# 2019-03-10 02:00:00                           NaN

# %%
df[df.isna().any(axis=1)]
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2013-06-14 09:00:00                   NaN                           NaN
# 2013-06-14 10:00:00                   NaN                           NaN
# 2014-03-09 02:00:00                   NaN                           NaN
# 2015-03-08 02:00:00                   NaN                           NaN
# 2015-04-21 11:00:00                   NaN                           NaN
# 2015-04-21 12:00:00                   NaN                           NaN
# 2016-03-13 02:00:00                   NaN                           NaN
# 2017-03-12 02:00:00                   NaN                           NaN
# 2018-03-11 02:00:00                   NaN                           NaN
# 2019-03-10 02:00:00                   NaN                           NaN
#
#                      Fremont Bridge West Sidewalk
# Date
# 2013-06-14 09:00:00                           NaN
# 2013-06-14 10:00:00                           NaN
# 2014-03-09 02:00:00                           NaN
# 2015-03-08 02:00:00                           NaN
# 2015-04-21 11:00:00                           NaN
# 2015-04-21 12:00:00                           NaN
# 2016-03-13 02:00:00                           NaN
# 2017-03-12 02:00:00                           NaN
# 2018-03-11 02:00:00                           NaN
# 2019-03-10 02:00:00                           NaN

# %%
df.loc['2015-04-20':'2015-04-22'].plot(figsize = (10,3))
# Out:
# <Axes: xlabel='Date'>

# %%
dfi = df.interpolate(method='piecewise_polynomial', axis=0);

# %%
(dfi['Fremont Bridge East Sidewalk'] + dfi['Fremont Bridge West Sidewalk'] != dfi['Fremont Bridge Total']).sum()
# Out:
# 0

# %%
# все правильно?
# точно?

# %%
display(dfi.loc['2015-04-21 09:00:00':'2015-04-21 15:00:00'])
dfi.loc['2015-04-20':'2015-04-22'].plot(figsize = (10,3))
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2015-04-21 09:00:00            339.000000                    207.000000
# 2015-04-21 10:00:00            116.000000                     65.000000
# 2015-04-21 11:00:00             95.333333                     51.333333
# 2015-04-21 12:00:00             74.666667                     37.666667
# 2015-04-21 13:00:00             54.000000                     24.000000
# 2015-04-21 14:00:00             84.000000                     44.000000
# 2015-04-21 15:00:00            139.000000                     63.000000
#
#                      Fremont Bridge West Sidewalk
# Date
# 2015-04-21 09:00:00                         132.0
# 2015-04-21 10:00:00                          51.0
# 2015-04-21 11:00:00                          44.0
# 2015-04-21 12:00:00                          37.0
# 2015-04-21 13:00:00                          30.0
# 2015-04-21 14:00:00                          40.0
# 2015-04-21 15:00:00                          76.0
# <Axes: xlabel='Date'>

# %%
# возвращаемся к df и округляем значения
# помним, что по идее лучше заполнить соседними РАНЕЕ нашей даты днями, кстати почему РАНЕЕ, 
# а не познее???df=dfi.round()
display(df.loc['2015-04-21 09:00:00':'2015-04-21 15:00:00'])
df.loc['2015-04-20':'2015-04-22'].plot(figsize = (10,3))
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2015-04-21 09:00:00                 339.0                         207.0
# 2015-04-21 10:00:00                 116.0                          65.0
# 2015-04-21 11:00:00                   NaN                           NaN
# 2015-04-21 12:00:00                   NaN                           NaN
# 2015-04-21 13:00:00                  54.0                          24.0
# 2015-04-21 14:00:00                  84.0                          44.0
# 2015-04-21 15:00:00                 139.0                          63.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2015-04-21 09:00:00                         132.0
# 2015-04-21 10:00:00                          51.0
# 2015-04-21 11:00:00                           NaN
# 2015-04-21 12:00:00                           NaN
# 2015-04-21 13:00:00                          30.0
# 2015-04-21 14:00:00                          40.0
# 2015-04-21 15:00:00                          76.0
# <Axes: xlabel='Date'>

# %% [markdown]
# Наличие сезонности в году и общего тренда год от года

# %%
sns.set()
df.plot(figsize = (10,3));

# %% [markdown]
# Наличие более мелких зависимостей недельной и температурной (зима/лето)

# %%
_=df.plot(figsize = (10,3));
_.set_xlim(datetime.datetime(2013,1,1),datetime.datetime(2013,8,31));

# %% [markdown]
# Наличие более мелких зависимостей недельной и температурной (зима/лето)
# и выходных

# %%
_=df.plot(figsize = (10,3))
_.set_xlim(datetime.datetime(2013,1,1),datetime.datetime(2013,1,15))
_.set_ylim(0,400);

# %% [markdown]
# Выявление зависимостей, на примере недельного агрегирования:
# - **сильно** через сумму
# - **слабо** через среднее

# %%
weekly=df.resample('W').sum()
weekly.plot(style=[':','--','-'], figsize = (10,3));
plt.show()
display(weekly.head(3))
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-07               14292.0                        7297.0
# 2012-10-14               16795.0                        8679.0
# 2012-10-21               15509.0                        7946.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-07                        6995.0
# 2012-10-14                        8116.0
# 2012-10-21                        7563.0

# %%
weekly=df.resample('W').mean()
weekly.plot(style=[':','--','-'], figsize = (10,3));
plt.show()
display(weekly.head(3))
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-07            119.100000                     60.808333
# 2012-10-14             99.970238                     51.660714
# 2012-10-21             92.315476                     47.297619
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-07                     58.291667
# 2012-10-14                     48.309524
# 2012-10-21                     45.017857

# %% [markdown]
# Cглаживание с переудом **30 отсчетов** с переносом результата в середину выборки

# %%
daily=df.resample('D').mean()
daily_mean=daily.rolling(30, center=True).mean()
daily_mean.plot(style=[':','--','-'], figsize = (10,3));

# %% [markdown]
# Cглаживание с переудом **30 дней отсчетов** с переносом результата в середину выборки, увы на месяц так не работает

# %%
daily_d=df.resample('D').mean()
daily_d.head()
daily_mean_d=daily_d.rolling('30D', center=True).mean()
daily_mean_d.plot(style=[':','--','-'], figsize = (10,3));

# %% [markdown]
# Посмотрите какую разницу дает подход окна по отсчетам и датам!!!

# %%
display(daily_mean.head(30))
display(daily_mean.tail(30))
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03                   NaN                           NaN
# 2012-10-04                   NaN                           NaN
# 2012-10-05                   NaN                           NaN
# 2012-10-06                   NaN                           NaN
# 2012-10-07                   NaN                           NaN
# 2012-10-08                   NaN                           NaN
# 2012-10-09                   NaN                           NaN
# 2012-10-10                   NaN                           NaN
# 2012-10-11                   NaN                           NaN
# 2012-10-12                   NaN                           NaN
# 2012-10-13                   NaN                           NaN
# 2012-10-14                   NaN                           NaN
# 2012-10-15                   NaN                           NaN
# 2012-10-16                   NaN                           NaN
# 2012-10-17                   NaN                           NaN
# 2012-10-18             94.147222                     48.368056
# 2012-10-19             92.698611                     47.791667
# 2012-10-20             89.194444                     46.131944
# 2012-10-21             86.226389                     44.729167
# 2012-10-22             87.343056                     45.215278
# 2012-10-23             87.830556                     45.348611
# 2012-10-24             86.694444                     44.761111
# 2012-10-25             85.569444                     44.200000
# 2012-10-26             84.418056                     43.648611
# 2012-10-27             81.948611                     42.406944
# 2012-10-28             80.027778                     41.441667
# 2012-10-29             81.229167                     42.030556
# 2012-10-30             83.158333                     42.895833
# 2012-10-31             83.612500                     43.026389
# 2012-11-01             82.895833                     42.672222
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-03                           NaN
# 2012-10-04                           NaN
# 2012-10-05                           NaN
# 2012-10-06                           NaN
# 2012-10-07                           NaN
# 2012-10-08                           NaN
# 2012-10-09                           NaN
# 2012-10-10                           NaN
# 2012-10-11                           NaN
# 2012-10-12                           NaN
# 2012-10-13                           NaN
# 2012-10-14                           NaN
# 2012-10-15                           NaN
# 2012-10-16                           NaN
# 2012-10-17                           NaN
# 2012-10-18                     45.779167
# 2012-10-19                     44.906944
# 2012-10-20                     43.062500
# 2012-10-21                     41.497222
# 2012-10-22                     42.127778
# 2012-10-23                     42.481944
# 2012-10-24                     41.933333
# 2012-10-25                     41.369444
# 2012-10-26                     40.769444
# 2012-10-27                     39.541667
# 2012-10-28                     38.586111
# 2012-10-29                     39.198611
# 2012-10-30                     40.262500
# 2012-10-31                     40.586111
# 2012-11-01                     40.223611
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-12-02            103.822222                     36.104167
# 2019-12-03            107.973611                     37.359722
# 2019-12-04            107.845833                     37.302778
# 2019-12-05            105.859722                     36.693056
# 2019-12-06            101.152778                     35.037500
# 2019-12-07             95.966667                     33.394444
# 2019-12-08             92.315278                     32.365278
# 2019-12-09             92.601389                     32.240278
# 2019-12-10             92.034722                     31.875000
# 2019-12-11             88.104167                     30.643056
# 2019-12-12             84.962500                     29.598611
# 2019-12-13             82.965278                     28.915278
# 2019-12-14             83.325000                     29.062500
# 2019-12-15             82.027778                     28.725000
# 2019-12-16             83.659722                     29.091667
# 2019-12-17             83.836111                     28.969444
# 2019-12-18                   NaN                           NaN
# 2019-12-19                   NaN                           NaN
# 2019-12-20                   NaN                           NaN
# 2019-12-21                   NaN                           NaN
# 2019-12-22                   NaN                           NaN
# 2019-12-23                   NaN                           NaN
# 2019-12-24                   NaN                           NaN
# 2019-12-25                   NaN                           NaN
# 2019-12-26                   NaN                           NaN
# 2019-12-27                   NaN                           NaN
# 2019-12-28                   NaN                           NaN
# 2019-12-29                   NaN                           NaN
# 2019-12-30                   NaN                           NaN
# 2019-12-31                   NaN                           NaN
#
#             Fremont Bridge West Sidewalk
# Date
# 2019-12-02                     67.718056
# 2019-12-03                     70.613889
# 2019-12-04                     70.543056
# 2019-12-05                     69.166667
# 2019-12-06                     66.115278
# 2019-12-07                     62.572222
# 2019-12-08                     59.950000
# 2019-12-09                     60.361111
# 2019-12-10                     60.159722
# 2019-12-11                     57.461111
# 2019-12-12                     55.363889
# 2019-12-13                     54.050000
# 2019-12-14                     54.262500
# 2019-12-15                     53.302778
# 2019-12-16                     54.568056
# 2019-12-17                     54.866667
# 2019-12-18                           NaN
# 2019-12-19                           NaN
# 2019-12-20                           NaN
# 2019-12-21                           NaN
# 2019-12-22                           NaN
# 2019-12-23                           NaN
# 2019-12-24                           NaN
# 2019-12-25                           NaN
# 2019-12-26                           NaN
# 2019-12-27                           NaN
# 2019-12-28                           NaN
# 2019-12-29                           NaN
# 2019-12-30                           NaN
# 2019-12-31                           NaN

# %%
daily_gauss = daily.rolling(30, center=True, win_type='gaussian').mean(std=3)
daily_gauss.plot(style=[':','--','-'], figsize = (10,3));

# %% [markdown]
# Возьмем все года, месяцы и дни и сгрупируем по часам, но тут есть проблемка ... которая делает наше решение **абсалютно некорректным**.

# %%
# красивые индексы времени
day_time=df.groupby(df.index.time).mean()
#hourly_ticks=day_time.index.values[::4]
#hourly_ticks
g=day_time.plot(style=[':','--','-'], figsize = (10,3));
#g.set_xticks(hourly_ticks);

# %% [markdown]
# Все-таки давайте посмотрим на неделю пристально

# %%
df.groupby(df.index.dayofweek).mean()
# Out:
#       Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 0               134.126213                     59.946869
# 1               143.133186                     64.255678
# 2               142.068122                     63.819444
# 3               134.727072                     60.921407
# 4               121.487100                     54.836053
# 5                63.766975                     32.163801
# 6                60.875138                     31.165343
#
#       Fremont Bridge West Sidewalk
# Date
# 0                        74.179343
# 1                        78.877508
# 2                        78.248677
# 3                        73.805666
# 4                        66.651047
# 5                        31.603175
# 6                        29.709795

# %%
week_day=df.groupby(df.index.dayofweek).mean()
week_name=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
week_day.index=week_name
g=week_day.plot(style=[':','--','-'], figsize = (10,5))

# %%
hourly_ticks=day_time.index.values[::4]
day_type=np.where(df.index.dayofweek<5,'Workday','Weekend')
by_day=df.groupby([day_type,df.index.time]).mean()

fig , ax = plt.subplots(1,2,figsize=(15,6))

by_day.loc['Workday'].plot(ax=ax[0],xticks=hourly_ticks,style=[':','--','-']);
by_day.loc['Weekend'].plot(ax=ax[1],xticks=hourly_ticks,style=[':','--','-']);

# %% [markdown]
# Крассивое визуализирование с учетом разброса данных относительно среднего

# %%
day_month=df.index.month
by_month_day=df.groupby([day_type, day_month, df.index.time]).mean()
display(by_month_day)
by_month_day.index.names
# Out:
#                        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
#         Date
# Weekend 1    00:00:00             10.000000                      4.283333
#              01:00:00              5.983333                      2.783333
#              02:00:00              3.600000                      1.766667
#              03:00:00              1.950000                      0.950000
#              04:00:00              2.366667                      1.066667
# ...                                     ...                           ...
# Workday 12   19:00:00             74.720000                     23.068571
#              20:00:00             40.114286                     13.880000
#              21:00:00             26.457143                      9.840000
#              22:00:00             18.200000                      7.731429
#              23:00:00             11.902857                      4.914286
#
#                        Fremont Bridge West Sidewalk
#         Date
# Weekend 1    00:00:00                      5.716667
#              01:00:00                      3.200000
#              02:00:00                      1.833333
#              03:00:00                      1.000000
#              04:00:00                      1.300000
# ...                                             ...
# Workday 12   19:00:00                     51.651429
#              20:00:00                     26.234286
#              21:00:00                     16.617143
#              22:00:00                     10.468571
#              23:00:00                      6.988571
#
# [576 rows x 3 columns]
# FrozenList([None, 'Date', None])

# %%
by_month_day.index.names=['day','month','time']
by_month_day
# Out:
#                         Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# day     month time
# Weekend 1     00:00:00             10.000000                      4.283333
#               01:00:00              5.983333                      2.783333
#               02:00:00              3.600000                      1.766667
#               03:00:00              1.950000                      0.950000
#               04:00:00              2.366667                      1.066667
# ...                                      ...                           ...
# Workday 12    19:00:00             74.720000                     23.068571
#               20:00:00             40.114286                     13.880000
#               21:00:00             26.457143                      9.840000
#               22:00:00             18.200000                      7.731429
#               23:00:00             11.902857                      4.914286
#
#                         Fremont Bridge West Sidewalk
# day     month time
# Weekend 1     00:00:00                      5.716667
#               01:00:00                      3.200000
#               02:00:00                      1.833333
#               03:00:00                      1.000000
#               04:00:00                      1.300000
# ...                                              ...
# Workday 12    19:00:00                     51.651429
#               20:00:00                     26.234286
#               21:00:00                     16.617143
#               22:00:00                     10.468571
#               23:00:00                      6.988571
#
# [576 rows x 3 columns]

# %%
df_1=by_month_day.reset_index()
df_1.head()
# Out:
#        day  month      time  Fremont Bridge Total  \
# 0  Weekend      1  00:00:00             10.000000
# 1  Weekend      1  01:00:00              5.983333
# 2  Weekend      1  02:00:00              3.600000
# 3  Weekend      1  03:00:00              1.950000
# 4  Weekend      1  04:00:00              2.366667
#
#    Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 0                      4.283333                      5.716667
# 1                      2.783333                      3.200000
# 2                      1.766667                      1.833333
# 3                      0.950000                      1.000000
# 4                      1.066667                      1.300000

# %%
sns.lineplot(x = df_1['time'].astype(str), 
             y='Fremont Bridge Total', 
             hue = 'day', 
             data = df_1);
plt.xticks(hourly_ticks.astype(str)); # обратите внимание на преобразование типов переменных

# %%
df_2 = df_1[df_1.month.isin([5,6,7,8,9])]
sns.lineplot( x=df_2['time'].astype(str), y='Fremont Bridge Total', hue='day', data=df_2)
plt.xticks(hourly_ticks.astype(str));

# %%
df_3 = df_1[df_1.month.isin([1,2])]
sns.lineplot( x=df_3['time'].astype(str), y='Fremont Bridge Total', hue='day', data=df_3, 
             estimator=np.median)
plt.xticks(hourly_ticks.astype(str));
