# %%
# Данные тут
# https://data.seattle.gov/Transportation/Fremont-Bridge-Hourly-Bicycle-Counts-by-Month-Octo/65db-xm6k/data


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import datetime

# %%
temp=pd.read_csv('datasets/Fremont_Bridge_Bicycle_Counter_2019.csv')
display(temp.tail(3))
temp.info()
# Out:
#                          Date  Fremont Bridge Total  \
# 62757  11/30/2019 09:00:00 PM                  13.0
# 62758  11/30/2019 10:00:00 PM                  19.0
# 62759  11/30/2019 11:00:00 PM                  12.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 62757                           6.0                           7.0
# 62758                          10.0                           9.0
# 62759                           6.0                           6.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62760 entries, 0 to 62759
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          62760 non-null  object
#  1   Fremont Bridge Total          62750 non-null  float64
#  2   Fremont Bridge East Sidewalk  62750 non-null  float64
#  3   Fremont Bridge West Sidewalk  62750 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 1.9+ MB

# %%
df=pd.read_csv('datasets/Fremont_Bridge_Bicycle_Counter_2019.csv',index_col='Date',parse_dates=True)

# %%
display(df.head(5))
display(df.tail(5))
df.info()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                  13.0                           4.0
# 2012-10-03 01:00:00                  10.0                           4.0
# 2012-10-03 02:00:00                   2.0                           1.0
# 2012-10-03 03:00:00                   5.0                           2.0
# 2012-10-03 04:00:00                   7.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-30 19:00:00                  20.0                          10.0
# 2019-11-30 20:00:00                  14.0                           8.0
# 2019-11-30 21:00:00                  13.0                           6.0
# 2019-11-30 22:00:00                  19.0                          10.0
# 2019-11-30 23:00:00                  12.0                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-30 19:00:00                          10.0
# 2019-11-30 20:00:00                           6.0
# 2019-11-30 21:00:00                           7.0
# 2019-11-30 22:00:00                           9.0
# 2019-11-30 23:00:00                           6.0
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 62760 entries, 2012-10-03 00:00:00 to 2019-11-30 23:00:00
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Fremont Bridge Total          62750 non-null  float64
#  1   Fremont Bridge East Sidewalk  62750 non-null  float64
#  2   Fremont Bridge West Sidewalk  62750 non-null  float64
# dtypes: float64(3)
# memory usage: 1.9 MB

# %%
(df['Fremont Bridge East Sidewalk'] + df['Fremont Bridge West Sidewalk'] != df['Fremont Bridge Total']).sum()
# Out:
# 10

# %%
df[  df['Fremont Bridge East Sidewalk'] + df['Fremont Bridge West Sidewalk'] != df['Fremont Bridge Total']  ]
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2013-06-14 09:00:00                   NaN                           NaN
# 2013-06-14 10:00:00                   NaN                           NaN
# 2014-03-09 02:00:00                   NaN                           NaN
# 2015-03-08 02:00:00                   NaN                           NaN
# 2015-04-21 11:00:00                   NaN                           NaN
# 2015-04-21 12:00:00                   NaN                           NaN
# 2016-03-13 02:00:00                   NaN                           NaN
# 2017-03-12 02:00:00                   NaN                           NaN
# 2018-03-11 02:00:00                   NaN                           NaN
# 2019-03-10 02:00:00                   NaN                           NaN
#
#                      Fremont Bridge West Sidewalk
# Date
# 2013-06-14 09:00:00                           NaN
# 2013-06-14 10:00:00                           NaN
# 2014-03-09 02:00:00                           NaN
# 2015-03-08 02:00:00                           NaN
# 2015-04-21 11:00:00                           NaN
# 2015-04-21 12:00:00                           NaN
# 2016-03-13 02:00:00                           NaN
# 2017-03-12 02:00:00                           NaN
# 2018-03-11 02:00:00                           NaN
# 2019-03-10 02:00:00                           NaN

# %%
df['2013-06-14']
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2013-06-14 00:00:00                  16.0                           5.0
# 2013-06-14 01:00:00                  14.0                           7.0
# 2013-06-14 02:00:00                   1.0                           1.0
# 2013-06-14 03:00:00                   6.0                           5.0
# 2013-06-14 04:00:00                  33.0                          20.0
# 2013-06-14 05:00:00                 154.0                         103.0
# 2013-06-14 06:00:00                 314.0                         225.0
# 2013-06-14 07:00:00                 417.0                         305.0
# 2013-06-14 08:00:00                 254.0                         160.0
# 2013-06-14 09:00:00                   NaN                           NaN
# 2013-06-14 10:00:00                   NaN                           NaN
# 2013-06-14 11:00:00                  43.0                          28.0
# 2013-06-14 12:00:00                  85.0                          50.0
# 2013-06-14 13:00:00                 108.0                          39.0
# 2013-06-14 14:00:00                 113.0                          44.0
# 2013-06-14 15:00:00                 181.0                          73.0
# 2013-06-14 16:00:00                 296.0                         122.0
# 2013-06-14 17:00:00                 516.0                         160.0
# 2013-06-14 18:00:00                 342.0                         120.0
# 2013-06-14 19:00:00                 148.0                          64.0
# 2013-06-14 20:00:00                 138.0                          72.0
# 2013-06-14 21:00:00                  68.0                          41.0
# 2013-06-14 22:00:00                  47.0                          31.0
# 2013-06-14 23:00:00                  28.0                          15.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2013-06-14 00:00:00                          11.0
# 2013-06-14 01:00:00                           7.0
# 2013-06-14 02:00:00                           0.0
# 2013-06-14 03:00:00                           1.0
# 2013-06-14 04:00:00                          13.0
# 2013-06-14 05:00:00                          51.0
# 2013-06-14 06:00:00                          89.0
# 2013-06-14 07:00:00                         112.0
# 2013-06-14 08:00:00                          94.0
# 2013-06-14 09:00:00                           NaN
# 2013-06-14 10:00:00                           NaN
# 2013-06-14 11:00:00                          15.0
# 2013-06-14 12:00:00                          35.0
# 2013-06-14 13:00:00                          69.0
# 2013-06-14 14:00:00                          69.0
# 2013-06-14 15:00:00                         108.0
# 2013-06-14 16:00:00                         174.0
# 2013-06-14 17:00:00                         356.0
# 2013-06-14 18:00:00                         222.0
# 2013-06-14 19:00:00                          84.0
# 2013-06-14 20:00:00                          66.0
# 2013-06-14 21:00:00                          27.0
# 2013-06-14 22:00:00                          16.0
# 2013-06-14 23:00:00                          13.0

# %%
dfi = df.interpolate(method='piecewise_polynomial', axis=0);

# %%
(dfi['Fremont Bridge East Sidewalk'] + dfi['Fremont Bridge West Sidewalk'] != dfi['Fremont Bridge Total']).sum()
# Out:
# 0

# %%
# все правильно?

# %%
# точно?

# %%
# все правильно?

# %%
# точно?

# %%
# все правильно?

# %%
# точно?

# %%
dfi.loc['2013-06-14 07:00:00':'2013-06-14 12:00:00'] # дробные велосипедисты не смущают?
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2013-06-14 07:00:00            417.000000                         305.0
# 2013-06-14 08:00:00            254.000000                         160.0
# 2013-06-14 09:00:00            183.666667                         116.0
# 2013-06-14 10:00:00            113.333333                          72.0
# 2013-06-14 11:00:00             43.000000                          28.0
# 2013-06-14 12:00:00             85.000000                          50.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2013-06-14 07:00:00                    112.000000
# 2013-06-14 08:00:00                     94.000000
# 2013-06-14 09:00:00                     67.666667
# 2013-06-14 10:00:00                     41.333333
# 2013-06-14 11:00:00                     15.000000
# 2013-06-14 12:00:00                     35.000000

# %%
# возвращаемся к df
df=dfi

# %%
sns.set()
df.plot();

# %%
_=df.plot()
_.set_xlim(datetime.datetime(2013,1,1),datetime.datetime(2013,6,1))
# Out:
# (376944.0, 380568.0)

# %%
_=df.plot()
_.set_xlim(datetime.datetime(2013,1,1),datetime.datetime(2013,1,15))
_.set_ylim(0,400);

# %%
weekly=df.resample('W').sum()
weekly.head(3)
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-07               14292.0                        7297.0
# 2012-10-14               16795.0                        8679.0
# 2012-10-21               15509.0                        7946.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-07                        6995.0
# 2012-10-14                        8116.0
# 2012-10-21                        7563.0

# %%
weekly.plot(style=[':','--','-']);

# %%
# сглаживание с переносом результата в середину выборки
daily=df.resample('D').sum()
display(daily.head(3))
daily_mean=daily.rolling(30,center=True).sum()
daily_mean.plot(style=[':','--','-']);
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03                3521.0                        1760.0
# 2012-10-04                3475.0                        1708.0
# 2012-10-05                3148.0                        1558.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-03                        1761.0
# 2012-10-04                        1767.0
# 2012-10-05                        1590.0

# %%
# сглаживание с переносом результата в середину выборки
display(daily_mean.head(30))
display(daily_mean.tail(30))
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03                   NaN                           NaN
# 2012-10-04                   NaN                           NaN
# 2012-10-05                   NaN                           NaN
# 2012-10-06                   NaN                           NaN
# 2012-10-07                   NaN                           NaN
# 2012-10-08                   NaN                           NaN
# 2012-10-09                   NaN                           NaN
# 2012-10-10                   NaN                           NaN
# 2012-10-11                   NaN                           NaN
# 2012-10-12                   NaN                           NaN
# 2012-10-13                   NaN                           NaN
# 2012-10-14                   NaN                           NaN
# 2012-10-15                   NaN                           NaN
# 2012-10-16                   NaN                           NaN
# 2012-10-17                   NaN                           NaN
# 2012-10-18               67786.0                       34825.0
# 2012-10-19               66743.0                       34410.0
# 2012-10-20               64220.0                       33215.0
# 2012-10-21               62083.0                       32205.0
# 2012-10-22               62887.0                       32555.0
# 2012-10-23               63238.0                       32651.0
# 2012-10-24               62420.0                       32228.0
# 2012-10-25               61610.0                       31824.0
# 2012-10-26               60781.0                       31427.0
# 2012-10-27               59003.0                       30533.0
# 2012-10-28               57620.0                       29838.0
# 2012-10-29               58485.0                       30262.0
# 2012-10-30               59874.0                       30885.0
# 2012-10-31               60201.0                       30979.0
# 2012-11-01               59685.0                       30724.0
#
#             Fremont Bridge West Sidewalk
# Date
# 2012-10-03                           NaN
# 2012-10-04                           NaN
# 2012-10-05                           NaN
# 2012-10-06                           NaN
# 2012-10-07                           NaN
# 2012-10-08                           NaN
# 2012-10-09                           NaN
# 2012-10-10                           NaN
# 2012-10-11                           NaN
# 2012-10-12                           NaN
# 2012-10-13                           NaN
# 2012-10-14                           NaN
# 2012-10-15                           NaN
# 2012-10-16                           NaN
# 2012-10-17                           NaN
# 2012-10-18                       32961.0
# 2012-10-19                       32333.0
# 2012-10-20                       31005.0
# 2012-10-21                       29878.0
# 2012-10-22                       30332.0
# 2012-10-23                       30587.0
# 2012-10-24                       30192.0
# 2012-10-25                       29786.0
# 2012-10-26                       29354.0
# 2012-10-27                       28470.0
# 2012-10-28                       27782.0
# 2012-10-29                       28223.0
# 2012-10-30                       28989.0
# 2012-10-31                       29222.0
# 2012-11-01                       28961.0
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01               96083.0                       33460.0
# 2019-11-02               94325.0                       33007.0
# 2019-11-03               92321.0                       32412.0
# 2019-11-04               94714.0                       33075.0
# 2019-11-05               97729.0                       33961.0
# 2019-11-06               99106.0                       34424.0
# 2019-11-07               99409.0                       34500.0
# 2019-11-08               98106.0                       34018.0
# 2019-11-09               94723.0                       32996.0
# 2019-11-10               92530.0                       32423.0
# 2019-11-11               94315.0                       32855.0
# 2019-11-12               95889.0                       33179.0
# 2019-11-13               94143.0                       32590.0
# 2019-11-14               90399.0                       31429.0
# 2019-11-15               88162.0                       30673.0
# 2019-11-16               84963.0                       29744.0
# 2019-11-17                   NaN                           NaN
# 2019-11-18                   NaN                           NaN
# 2019-11-19                   NaN                           NaN
# 2019-11-20                   NaN                           NaN
# 2019-11-21                   NaN                           NaN
# 2019-11-22                   NaN                           NaN
# 2019-11-23                   NaN                           NaN
# 2019-11-24                   NaN                           NaN
# 2019-11-25                   NaN                           NaN
# 2019-11-26                   NaN                           NaN
# 2019-11-27                   NaN                           NaN
# 2019-11-28                   NaN                           NaN
# 2019-11-29                   NaN                           NaN
# 2019-11-30                   NaN                           NaN
#
#             Fremont Bridge West Sidewalk
# Date
# 2019-11-01                       62623.0
# 2019-11-02                       61318.0
# 2019-11-03                       59909.0
# 2019-11-04                       61639.0
# 2019-11-05                       63768.0
# 2019-11-06                       64682.0
# 2019-11-07                       64909.0
# 2019-11-08                       64088.0
# 2019-11-09                       61727.0
# 2019-11-10                       60107.0
# 2019-11-11                       61460.0
# 2019-11-12                       62710.0
# 2019-11-13                       61553.0
# 2019-11-14                       58970.0
# 2019-11-15                       57489.0
# 2019-11-16                       55219.0
# 2019-11-17                           NaN
# 2019-11-18                           NaN
# 2019-11-19                           NaN
# 2019-11-20                           NaN
# 2019-11-21                           NaN
# 2019-11-22                           NaN
# 2019-11-23                           NaN
# 2019-11-24                           NaN
# 2019-11-25                           NaN
# 2019-11-26                           NaN
# 2019-11-27                           NaN
# 2019-11-28                           NaN
# 2019-11-29                           NaN
# 2019-11-30                           NaN

# %%
daily_gauss=daily.rolling(60,center=True,win_type='gaussian').sum(std=10)
daily_gauss.plot(style=[':','--','-']);

# %%
day_time=df.groupby(df.index.time).mean()
#  внимание смотреть тут  https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DatetimeIndex.html

hourly_ticks=day_time.index.values[::4] # что это?

g=day_time.plot(style=[':','--','-']);
g.set_xticks(hourly_ticks);

# %%
df.groupby(df.index.dayofweek).mean()
# Out:
#       Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 0               134.347073                     60.208557
# 1               143.656055                     64.659182
# 2               142.501783                     64.143271
# 3               135.092469                     61.217580
# 4               121.845811                     55.119207
# 5                64.168672                     32.382353
# 6                61.153597                     31.326408
#
#       Fremont Bridge West Sidewalk
# Date
# 0                        74.138517
# 1                        78.996872
# 2                        78.358512
# 3                        73.874889
# 4                        66.726604
# 5                        31.786319
# 6                        29.827189

# %%
week_day=df.groupby(df.index.dayofweek).mean()

week_name=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']
week_day.index = week_name
display(week_day)

g=week_day.plot(style=[':','--','-'])
#g.set_xticks(np.arange(len(week_name)));# тут нужно объяснить, что , поэтому танец с бубном!
#g.set_xticklabels(week_name);
# Out:
#      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Mon            134.347073                     60.208557
# Tue            143.656055                     64.659182
# Wed            142.501783                     64.143271
# Thu            135.092469                     61.217580
# Fri            121.845811                     55.119207
# Sat             64.168672                     32.382353
# Sun             61.153597                     31.326408
#
#      Fremont Bridge West Sidewalk
# Mon                     74.138517
# Tue                     78.996872
# Wed                     78.358512
# Thu                     73.874889
# Fri                     66.726604
# Sat                     31.786319
# Sun                     29.827189

# %%
day_type=np.where(df.index.dayofweek<5,'Workday','Weekend')
by_day=df.groupby([day_type,df.index.time]).mean()

fig , ax = plt.subplots(1,2,figsize=(15,5))

by_day.loc['Workday'].plot(ax=ax[0],xticks=hourly_ticks,style=[':','--','-']);
by_day.loc['Weekend'].plot(ax=ax[1],xticks=hourly_ticks,style=[':','--','-']);

# %%
day_month=df.index.month
by_month_day=df.groupby([day_month,day_type,df.index.time]).mean()
display(by_month_day.head())
by_month_day.index.names
# Out:
#                        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 1    Weekend 00:00:00             10.000000                      4.283333
#              01:00:00              5.983333                      2.783333
#              02:00:00              3.600000                      1.766667
#              03:00:00              1.950000                      0.950000
#              04:00:00              2.366667                      1.066667
#
#                        Fremont Bridge West Sidewalk
# Date
# 1    Weekend 00:00:00                      5.716667
#              01:00:00                      3.200000
#              02:00:00                      1.833333
#              03:00:00                      1.000000
#              04:00:00                      1.300000
# FrozenList(['Date', None, None])

# %%
by_month_day.index.names=['month','day','time']
by_month_day.head()
# Out:
#                         Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# month day     time
# 1     Weekend 00:00:00             10.000000                      4.283333
#               01:00:00              5.983333                      2.783333
#               02:00:00              3.600000                      1.766667
#               03:00:00              1.950000                      0.950000
#               04:00:00              2.366667                      1.066667
#
#                         Fremont Bridge West Sidewalk
# month day     time
# 1     Weekend 00:00:00                      5.716667
#               01:00:00                      3.200000
#               02:00:00                      1.833333
#               03:00:00                      1.000000
#               04:00:00                      1.300000

# %%
df_1=by_month_day.reset_index()
df_1.head()
# Out:
#    month      day      time  Fremont Bridge Total  \
# 0      1  Weekend  00:00:00             10.000000
# 1      1  Weekend  01:00:00              5.983333
# 2      1  Weekend  02:00:00              3.600000
# 3      1  Weekend  03:00:00              1.950000
# 4      1  Weekend  04:00:00              2.366667
#
#    Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 0                      4.283333                      5.716667
# 1                      2.783333                      3.200000
# 2                      1.766667                      1.833333
# 3                      0.950000                      1.000000
# 4                      1.066667                      1.300000

# %%
pd.set_option("plotting.matplotlib.register_converters", True) # это заплатка !!!
sns.lineplot(x='time', y='Fremont Bridge Total', hue='day', data= df_1);
plt.xticks(hourly_ticks); # без этого часы не красивые

# %%
df_2=df_1[df_1.month.isin([5,6,7,8,9])]
sns.lineplot( x='time', y='Fremont Bridge Total', hue='day', data=df_2)
plt.xticks(hourly_ticks);

# %%
df_2=df_1[df_1.month.isin([1,2])]
sns.lineplot( x='time', y='Fremont Bridge Total', hue='day', data=df_2, estimator=np.median)
plt.xticks(hourly_ticks);
