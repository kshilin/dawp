# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Временные ряды
# ## Пакет Datetime

# %%
from datetime import datetime

# %%
from datetime import datetime
now = datetime.now()
print('сейчас ',now)
display(now)

print('сейчас год ',now.year) 
print('сейчас месяц ',now.month)
print('сейчас день ',now.day)
# Out:
# сейчас  2026-04-28 11:52:26.875955
# datetime.datetime(2026, 4, 28, 11, 52, 26, 875955)
# сейчас год  2026
# сейчас месяц  4
# сейчас день  28

# %%
from datetime import timedelta


from datetime import timedelta
start = datetime(2020, 1, 1)
start + timedelta(12)
# Out:
# datetime.datetime(2020, 1, 13, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2019, 12, 8, 0, 0)

# %%
# разнича считается в днях и секундах!
start + timedelta(12,24000,1)
# Out:
# datetime.datetime(2020, 1, 13, 6, 40, 0, 1)

# %% [markdown]
# ## Конвертирование даты/времени строка<-->время

# %%
stamp = datetime(2011, 1, 3)
str(stamp)
stamp.strftime('%Y-%m-%d')
# Out:
# '2011-01-03'

# %%
stamp.strftime('%y-%m-%d')
# Out:
# '11-01-03'

# %%
value = '2011-01-03'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
value = '01.03.20 23:39'
datetime.strptime(value, '%d.%m.%y %H:%M')
# Out:
# datetime.datetime(2020, 3, 1, 23, 39)

# %%
datestrs = ['10/1/2020', '12/2/2020']

# американская традиция записи
[datetime.strptime(x, '%m/%d/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2020, 10, 1, 0, 0), datetime.datetime(2020, 12, 2, 0, 0)]

# %%
# российская и европейская традиция записи
[datetime.strptime(x, '%d/%m/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2020, 1, 10, 0, 0), datetime.datetime(2020, 2, 12, 0, 0)]

# %% [markdown]
# |Спецификатор|Описание|
# |:------|:---------------------------------------|
# | %Y   | Год с четырьмя цифрами                |
# | %y   | Год с двумя цифрами                   |
# | %m   | Номер месяца с двумя цифрами [01, 12] |
# |  %d  | Номер дня с двумя цифрами [01, 31]    |
# | %H   | Час (в 24-часовом формате) [00, 23]   |
# | %I   | Час (в 12-часовом формате) [01, 12]   |
# | %M   | Минута с двумя цифрами [01, 59]       |
# | %S   | Секунда [00, 61] (секунды 60 и 61 високосные)                                      |
# | %w  | День недели в виде целого числа [0 (воскресенье), 6]                               |
# | %U  | Номер недели в году [00, 53]. Первым днем недели считается воскресенье, а дни, предшествующие первому воскресенью, относятся к неделе 0  |
# | %W  | Номер недели в году [00, 53]. Первым днем недели считается понедельник, а дни, предшествующие первому понедельнику, относятся к неделе 0 |
# | %z  | Часовой пояс UTC в виде +HHMM или –HHMM; пустая строка, если часовой пояс не учитывается                                                 |
# | %F  | Сокращение для %Y–%m–%d, например 2012–4–18 %D Сокращение для %m/%d/%y, например 04/18/12                                                |

# %% [markdown]
# ## Стандартный парсер

# %%
from dateutil.parser import parse
parse('2011-01-03')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
parse('Jan 31, 1997 10:45 PM')
# Out:
# datetime.datetime(1997, 1, 31, 22, 45)

# %%
# не правильный парсер для России
parse('6/12/2011')
# Out:
# datetime.datetime(2011, 6, 12, 0, 0)

# %%
# правильный парсер для России
parse('6/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 6, 0, 0)

# %% [markdown]
# ## Pandas парсер

# %%
datestrs = ['2011-07-06 12:00:00', '2011-08-06 00:00:00']
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
idx = pd.to_datetime(datestrs + [None]) # или np.nan (к вопросу о отображении пропущенного времени)
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
# проверим поиск пропущенных данных
pd.isna(idx)
# Out:
# array([False, False,  True])

# %% [markdown]
# ## Введение во временные индексы

# %%
from datetime import datetime
dates = [datetime(2020, 1, 2), datetime(2020, 1, 5),
         datetime(2020, 1, 7), datetime(2020, 1, 8),
         datetime(2020, 1, 10), datetime(2020, 1, 12)]

np.random.seed(42)
ts = pd.Series(np.random.randn(6), index=dates)
ts
# Out:
# 2020-01-02    0.496714
# 2020-01-05   -0.138264
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# 2020-01-10   -0.234153
# 2020-01-12   -0.234137
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-05', '2020-01-07', '2020-01-08',
#                '2020-01-10', '2020-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts[::2]+ts
# Out:
# 2020-01-02    0.993428
# 2020-01-05         NaN
# 2020-01-07    1.295377
# 2020-01-08         NaN
# 2020-01-10   -0.468307
# 2020-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
stamp = ts.index[0]
stamp
# Out:
# Timestamp('2020-01-02 00:00:00')

# %% [markdown]
# ### Индексирование, выбор, подмножество

# %%
stamp = ts.index[2]
display(stamp)
ts[stamp]
# Out:
# Timestamp('2020-01-07 00:00:00')
# np.float64(0.6476885381006925)

# %%
ts['1/10/2020']
# Out:
# np.float64(-0.23415337472333597)

# %%
ts['20200110']  # почему я так записал
# Out:
# np.float64(-0.23415337472333597)

# %%
longer_ts = pd.Series(np.random.randn(1000),
                      index=pd.date_range('1/1/2000', periods=1000))
longer_ts
# Out:
# 2000-01-01    1.579213
# 2000-01-02    0.767435
# 2000-01-03   -0.469474
# 2000-01-04    0.542560
# 2000-01-05   -0.463418
#                 ...
# 2002-09-22    0.924634
# 2002-09-23    0.059630
# 2002-09-24   -0.646937
# 2002-09-25    0.698223
# 2002-09-26    0.393485
# Freq: D, Length: 1000, dtype: float64

# %%
longer_ts['2001']
# Out:
# 2001-01-01    1.451144
# 2001-01-02    0.959271
# 2001-01-03    2.153182
# 2001-01-04   -0.767348
# 2001-01-05    0.872321
#                 ...
# 2001-12-27    0.408253
# 2001-12-28   -1.702584
# 2001-12-29    1.029156
# 2001-12-30    0.472597
# 2001-12-31    0.256030
# Freq: D, Length: 365, dtype: float64

# %%
longer_ts['2001-05']
# Out:
# 2001-05-01    0.077368
# 2001-05-02   -0.861284
# 2001-05-03    1.523124
# 2001-05-04    0.538910
# 2001-05-05   -1.037246
# 2001-05-06   -0.190339
# 2001-05-07   -0.875618
# 2001-05-08   -1.382800
# 2001-05-09    0.926178
# 2001-05-10    1.909417
# 2001-05-11   -1.398568
# 2001-05-12    0.562969
# 2001-05-13   -0.650643
# 2001-05-14   -0.487125
# 2001-05-15   -0.592394
# 2001-05-16   -0.863991
# 2001-05-17    0.048522
# 2001-05-18   -0.830950
# 2001-05-19    0.270457
# 2001-05-20   -0.050238
# 2001-05-21   -0.238948
# 2001-05-22   -0.907564
# 2001-05-23   -0.576771
# 2001-05-24    0.755391
# 2001-05-25    0.500917
# 2001-05-26   -0.977555
# 2001-05-27    0.099332
# 2001-05-28    0.751387
# 2001-05-29   -1.669405
# 2001-05-30    0.543360
# 2001-05-31   -0.662624
# Freq: D, dtype: float64

# %%
display(ts)
ts[datetime(2020, 1, 7):]
# Out:
# 2020-01-02    0.496714
# 2020-01-05   -0.138264
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# 2020-01-10   -0.234153
# 2020-01-12   -0.234137
# dtype: float64
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# 2020-01-10   -0.234153
# 2020-01-12   -0.234137
# dtype: float64

# %%
ts
ts['1/6/2020':'1/11/2020']
# Out:
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# 2020-01-10   -0.234153
# dtype: float64

# %%
ts.truncate(after='1/9/2020')
# Out:
# 2020-01-02    0.496714
# 2020-01-05   -0.138264
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# dtype: float64

# %%
ts.truncate(after='2020-01-09') # возможен вариант before
# Out:
# 2020-01-02    0.496714
# 2020-01-05   -0.138264
# 2020-01-07    0.647689
# 2020-01-08    1.523030
# dtype: float64

# %%
dates = pd.date_range('2000-01-01', periods=100, freq='W-WED')
long_df = pd.DataFrame(np.random.randn(100, 4),
                       index=dates,
                       columns=['Colorado', 'Texas',
                                'New York', 'Ohio'])
long_df.loc['2001-05']
# Out:
#             Colorado     Texas  New York      Ohio
# 2001-05-02  0.708109  0.956702 -0.785989 -1.331233
# 2001-05-09 -1.836205  0.507991 -1.103367 -2.152891
# 2001-05-16  0.388579  2.493000 -0.006071  0.838491
# 2001-05-23  0.081829 -0.098890  0.919076 -0.290275
# 2001-05-30  0.267392  0.321698 -0.668090  0.992042

# %% [markdown]
# ### Временной ряд с дубликатами индексов

# %%
dates = pd.DatetimeIndex(['1/1/2000', 
                          '1/2/2000', 
                          '1/2/2000',
                          '1/2/2000', 
                          '1/3/2000'])
dup_ts = pd.Series(np.arange(5), index=dates)
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
# индекс без дубликата
dup_ts['1/3/2000']
# Out:
# np.int64(4)

# %%
# индекс с дубликатом
dup_ts['1/2/2000']
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
grouped = dup_ts.groupby(level=0)
grouped.mean()
# Out:
# 2000-01-01    0.0
# 2000-01-02    2.0
# 2000-01-03    4.0
# dtype: float64

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %% [markdown]
# ## Диапазоны дат, частоты и сдвиги
#
# ### Гененрируем даты

# %%
index = pd.date_range('2012-04-01', '2012-06-01')
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2012-04-01', periods=20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end='2012-06-01', periods=20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# Неполный список частот временных рядов (только основные)
#
# | Обозначение             | Тип смещения        | Описание                                                                                                                                                                             |
# |:-------------------------|:---------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | D                       | Day                 | Ежедневно                                                                                                                                                                            |
# | B                       | BusinessDay         | Каждый рабочий день                                                                                                                                                                  |
# | H                       | Hour                | Ежечасно                                                                                                                                                                             |
# | min               | Minute              | Ежеминутно                                                                                                                                                                           |
# | S                       | Second              | Ежесекундно                                                                                                                                                                          |
# | L или ms                | Milli               | Каждую миллисекунду                                                                                                                                                                  |
# | U                       | Micro               | Каждую микросекунду                                                                                                                                                                  |
# | ME                       | MonthEnd            | Последний календарный день месяца                                                                                                                                                    |
# | BME                      | BusinessMonthEnd    | Последний рабочий день месяца                                                                                                                                                        |
# | MS                      | MonthBegin          | Первый календарный день месяца                                                                                                                                                       |
# | BMS                     | BusinessMonthBegin  | Первый рабочий день месяца                                                                                                                                                           |
# | W–MON, W–TUE, ...       | Week                | Еженедельно в указанный день: MON, TUE, WED, THU, FRI, SAT, SUN                                                                                                                      |
# | WOM–1MON, WOM–2MON, ... | WeekOfMonth         | Указанный день первой, второй, третьей или четвертой недели месяца. Например, WOM–3FRI означает третью пятницу каждого месяца                                                        |
# | Q–JAN, Q–FEB, ...       | QuarterEnd          | Ежеквартально с привязкой к последнему календарному дню каждого месяца, считая, что год заканчивается в указанном месяце: JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC |
# | BQ–JAN, BQ–FEB, . . .  | BusinessQuarterEnd    | Ежеквартально с привязкой к последнему рабочему дню каждого месяца, считая, что год заканчивается в указанном месяце              |
# | QS–JAN, QS–FEB, . . .  | QuarterBegin          | Ежеквартально с привязкой к первому календарному дню каждого месяца, считая, что год заканчивается в указанном месяце             |
# | BQS–JAN, BQS–FEB, ...  | BusinessQuarterBegin  | Ежеквартально с привязкой к первому рабочему дню каждого месяца, считая, что год заканчивается в указанном месяце                 |
# | Y–JAN, Y–FEB, ...      | YearEnd               | Ежегодно с привязкой к последнему календарному дню указанного месяца: JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC  |
# | BA–JAN, BA–FEB, . . .  | BusinessYearEnd       | Ежегодно с привязкой к последнему рабочему дню указанного месяца                                                                  |
# | AS–JAN, AS–FEB, . . .  | YearBegin             | Ежегодно с привязкой к первому календарному дню указанного месяца                                                                 |
# | BAS–JAN, BAS–FEB, ...  | BusinessYearBegin     | Ежегодно с привязкой к первому рабочему дню указанного месяца                                                                     |

# %%
pd.date_range('2000-01-01', '2000-12-01', freq='BME')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30'],
#               dtype='datetime64[ns]', freq='BME')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5)
# Out:
# DatetimeIndex(['2012-05-02 12:56:31', '2012-05-03 12:56:31',
#                '2012-05-04 12:56:31', '2012-05-05 12:56:31',
#                '2012-05-06 12:56:31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2012-05-02 12:56:31', periods=5, normalize=True)
# Out:
# DatetimeIndex(['2012-05-02', '2012-05-03', '2012-05-04', '2012-05-05',
#                '2012-05-06'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ### Частоты и смещение дат

# %%
# смещением даты (date offset)
from pandas.tseries.offsets import Hour, Minute

hour = Hour()
hour

# %%
# смещение даты на 4 часа
pd.date_range('2000-01-01', '2000-01-03 23:59', freq='4h')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4h')

# %%
# смещение даты на 1 час 30 мин
pd.date_range('2000-01-01', periods=10, freq='1h30min')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90min')

# %% [markdown]
# ### Даты, связанные с неделей месяца

# %%
# WOM понедельно месяц
# WOM-3FRI каждая третья пятница в месяце
rng = pd.date_range('2012-01-01', '2012-09-01', freq='WOM-3FRI') 
list(rng)
# Out:
# [Timestamp('2012-01-20 00:00:00'),
#  Timestamp('2012-02-17 00:00:00'),
#  Timestamp('2012-03-16 00:00:00'),
#  Timestamp('2012-04-20 00:00:00'),
#  Timestamp('2012-05-18 00:00:00'),
#  Timestamp('2012-06-15 00:00:00'),
#  Timestamp('2012-07-20 00:00:00'),
#  Timestamp('2012-08-17 00:00:00')]

# %% [markdown]
# ### Сдвиг всех данных сразу

# %%
per=10
ts = pd.Series(range(per), index=pd.date_range('1/1/2000', periods=per, freq='W'))+1
ts
# Out:
# 2000-01-02     1
# 2000-01-09     2
# 2000-01-16     3
# 2000-01-23     4
# 2000-01-30     5
# 2000-02-06     6
# 2000-02-13     7
# 2000-02-20     8
# 2000-02-27     9
# 2000-03-05    10
# Freq: W-SUN, dtype: int64

# %%
ts.shift(2)
# Out:
# 2000-01-02    NaN
# 2000-01-09    NaN
# 2000-01-16    1.0
# 2000-01-23    2.0
# 2000-01-30    3.0
# 2000-02-06    4.0
# 2000-02-13    5.0
# 2000-02-20    6.0
# 2000-02-27    7.0
# 2000-03-05    8.0
# Freq: W-SUN, dtype: float64

# %%
ts.shift(-2)
# Out:
# 2000-01-02     3.0
# 2000-01-09     4.0
# 2000-01-16     5.0
# 2000-01-23     6.0
# 2000-01-30     7.0
# 2000-02-06     8.0
# 2000-02-13     9.0
# 2000-02-20    10.0
# 2000-02-27     NaN
# 2000-03-05     NaN
# Freq: W-SUN, dtype: float64

# %%
# процентный прирост
ts / ts.shift(1) - 1
# Out:
# 2000-01-02         NaN
# 2000-01-09    1.000000
# 2000-01-16    0.500000
# 2000-01-23    0.333333
# 2000-01-30    0.250000
# 2000-02-06    0.200000
# 2000-02-13    0.166667
# 2000-02-20    0.142857
# 2000-02-27    0.125000
# 2000-03-05    0.111111
# Freq: W-SUN, dtype: float64

# %%
# процентный приростот нуля
(ts / ts.shift(1)-1).fillna(0)
# Out:
# 2000-01-02    0.000000
# 2000-01-09    1.000000
# 2000-01-16    0.500000
# 2000-01-23    0.333333
# 2000-01-30    0.250000
# 2000-02-06    0.200000
# 2000-02-13    0.166667
# 2000-02-20    0.142857
# 2000-02-27    0.125000
# 2000-03-05    0.111111
# Freq: W-SUN, dtype: float64

# %%
# данные на месте сдвигаем время
display (ts)
ts.shift(2, freq='D')
# Out:
# 2000-01-02     1
# 2000-01-09     2
# 2000-01-16     3
# 2000-01-23     4
# 2000-01-30     5
# 2000-02-06     6
# 2000-02-13     7
# 2000-02-20     8
# 2000-02-27     9
# 2000-03-05    10
# Freq: W-SUN, dtype: int64
# 2000-01-04     1
# 2000-01-11     2
# 2000-01-18     3
# 2000-01-25     4
# 2000-02-01     5
# 2000-02-08     6
# 2000-02-15     7
# 2000-02-22     8
# 2000-02-29     9
# 2000-03-07    10
# dtype: int64

# %%
display (ts)
ts.shift(2, freq='ME')
# Out:
# 2000-01-02     1
# 2000-01-09     2
# 2000-01-16     3
# 2000-01-23     4
# 2000-01-30     5
# 2000-02-06     6
# 2000-02-13     7
# 2000-02-20     8
# 2000-02-27     9
# 2000-03-05    10
# Freq: W-SUN, dtype: int64
# 2000-02-29     1
# 2000-02-29     2
# 2000-02-29     3
# 2000-02-29     4
# 2000-02-29     5
# 2000-03-31     6
# 2000-03-31     7
# 2000-03-31     8
# 2000-03-31     9
# 2000-04-30    10
# dtype: int64

# %%
ts.shift(-1, freq='D')
# Out:
# 2000-01-01     1
# 2000-01-08     2
# 2000-01-15     3
# 2000-01-22     4
# 2000-01-29     5
# 2000-02-05     6
# 2000-02-12     7
# 2000-02-19     8
# 2000-02-26     9
# 2000-03-04    10
# dtype: int64

# %%
ts.shift(1, freq='90min')
# Out:
# 2000-01-02 01:30:00     1
# 2000-01-09 01:30:00     2
# 2000-01-16 01:30:00     3
# 2000-01-23 01:30:00     4
# 2000-01-30 01:30:00     5
# 2000-02-06 01:30:00     6
# 2000-02-13 01:30:00     7
# 2000-02-20 01:30:00     8
# 2000-02-27 01:30:00     9
# 2000-03-05 01:30:00    10
# dtype: int64

# %%
### Применение даты времени с группировкой - resample

# %%
np.random.seed(42)
ts = pd.Series(np.random.randn(20), index=pd.date_range('1/15/2000', periods=20, freq='4d'))
ts
# Out:
# 2000-01-15    0.496714
# 2000-01-19   -0.138264
# 2000-01-23    0.647689
# 2000-01-27    1.523030
# 2000-01-31   -0.234153
# 2000-02-04   -0.234137
# 2000-02-08    1.579213
# 2000-02-12    0.767435
# 2000-02-16   -0.469474
# 2000-02-20    0.542560
# 2000-02-24   -0.463418
# 2000-02-28   -0.465730
# 2000-03-03    0.241962
# 2000-03-07   -1.913280
# 2000-03-11   -1.724918
# 2000-03-15   -0.562288
# 2000-03-19   -1.012831
# 2000-03-23    0.314247
# 2000-03-27   -0.908024
# 2000-03-31   -1.412304
# Freq: 4D, dtype: float64

# %%
ts.resample('ME').mean()
# Out:
# 2000-01-31    0.459003
# 2000-02-29    0.179493
# 2000-03-31   -0.872179
# Freq: ME, dtype: float64

# %% [markdown]
# ### Локализация и преобразование часовых поясов
# Можно посмотреть самостоятельно (Маккини Python и анализ данных) стр. 355-359
# Это бывает важно, например при совмещении ряда американского и российского рынка.

# %% [markdown]
# ## Временные периоды

# %%
rng = pd.date_range('2000-01-01', periods=3, freq='ME')
display(rng)
ts = pd.Series(np.random.randn(3), index=rng)
ts
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31'], dtype='datetime64[ns]', freq='ME')
# 2000-01-31    1.465649
# 2000-02-29   -0.225776
# 2000-03-31    0.067528
# Freq: ME, dtype: float64

# %%
p = pd.Period('2020', freq='Y-DEC')
p
# Out:
# Period('2020', 'Y-DEC')

# %%
p.asfreq('D', 'start')
# Out:
# Period('2020-01-01', 'D')

# %%
p.asfreq('D', 'end')
# Out:
# Period('2020-12-31', 'D')

# %%
rng = pd.period_range('2006','2009', freq='Y-DEC')
rng
# Out:
# PeriodIndex(['2006', '2007', '2008', '2009'], dtype='period[Y-DEC]')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2006   -1.424748
# 2007   -0.544383
# 2008    0.110923
# 2009   -1.150994
# Freq: Y-DEC, dtype: float64

# %%
# на первый день месяца
ts.asfreq('M', how='start')
# Out:
# 2006-01   -1.424748
# 2007-01   -0.544383
# 2008-01    0.110923
# 2009-01   -1.150994
# Freq: M, dtype: float64

# %%
ts
# Out:
# 2006   -1.424748
# 2007   -0.544383
# 2008    0.110923
# 2009   -1.150994
# Freq: Y-DEC, dtype: float64

# %%
# на последний бизнес день месяца
ts.asfreq('B', how='start')
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/4075971205.py:2: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ts.asfreq('B', how='start')
# 2006-01-02   -1.424748
# 2007-01-01   -0.544383
# 2008-01-01    0.110923
# 2009-01-01   -1.150994
# Freq: B, dtype: float64

# %% [markdown]
# ### Квартальная частота периода

# %% [markdown]
# Квартальные данные стандартно применяются в бухгалтерии, финансах и других областях. Обычно квартальные итоги подводятся относительно конца финансового года, каковым считается последний календарный или рабочий день одного из 12 месяцев.
#
# Следовательно, период 2012Q4 интерпретируется по-разному в зависимости от того, что понимать под концом финансового года.
#
# Библиотека pandas поддерживает все 12 возможных значений кварталь- ной частоты – от Q–JAN до Q–DEC:
#
#
# [<img src="Quart.pdf" width="750"/>](Quart.pdf)

# %%
data = pd.read_csv('macrodata.csv')
display(data.head(5))
display(data.tail(5))
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19
#        year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 198  2008.0      3.0  13324.600    9267.7  1990.693   991.551   9838.3
# 199  2008.0      4.0  13141.920    9195.3  1857.661  1007.273   9920.4
# 200  2009.0      1.0  12925.410    9209.2  1558.494   996.287   9926.4
# 201  2009.0      2.0  12901.504    9189.0  1456.678  1023.528  10077.5
# 202  2009.0      3.0  12990.341    9256.0  1486.398  1044.088  10040.6
#
#          cpi      m1  tbilrate  unemp      pop  infl  realint
# 198  216.889  1474.7      1.17    6.0  305.270 -3.16     4.33
# 199  212.174  1576.5      0.12    6.9  305.952 -8.79     8.91
# 200  212.671  1592.8      0.22    8.1  306.547  0.94    -0.71
# 201  214.469  1653.6      0.18    9.2  307.226  3.37    -3.19
# 202  216.385  1673.9      0.12    9.6  308.013  3.56    -3.44

# %%
index = pd.PeriodIndex.from_fields(year=data.year, quarter=data.quarter,
                       freq='Q-DEC')
index
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', length=203)

# %%
data.index = index
data.head(5)
# Out:
#           year  quarter   realgdp  realcons  realinv  realgovt  realdpi  \
# 1959Q1  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9
# 1959Q2  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7
# 1959Q3  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4
# 1959Q4  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3
# 1960Q1  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5
#
#           cpi     m1  tbilrate  unemp      pop  infl  realint
# 1959Q1  28.98  139.7      2.82    5.8  177.146  0.00     0.00
# 1959Q2  29.15  141.7      3.08    5.1  177.830  2.34     0.74
# 1959Q3  29.35  140.5      3.82    5.3  178.657  2.74     1.09
# 1959Q4  29.37  140.0      4.33    5.6  179.386  0.27     4.06
# 1960Q1  29.54  139.6      3.50    5.2  180.007  2.31     1.19

# %% [markdown]
# ## Передискретизация

# %%
np.random.seed(42)
rng = pd.date_range('2000-01-01', periods=100, freq='D')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2000-01-01    0.496714
# 2000-01-02   -0.138264
# 2000-01-03    0.647689
# 2000-01-04    1.523030
# 2000-01-05   -0.234153
#                 ...
# 2000-04-05   -1.463515
# 2000-04-06    0.296120
# 2000-04-07    0.261055
# 2000-04-08    0.005113
# 2000-04-09   -0.234587
# Freq: D, Length: 100, dtype: float64

# %%
# привязка к последней дате
ts.resample('ME').mean()
# Out:
# 2000-01-31   -0.201488
# 2000-02-29   -0.104592
# 2000-03-31    0.015601
# 2000-04-30   -0.176555
# Freq: ME, dtype: float64

# %%
# привязка к периоду
ts.resample('ME', kind='period').mean()
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/3432444038.py:2: FutureWarning: The 'kind' keyword in Series.resample is deprecated and will be removed in a future version. Explicitly cast the index to the desired type instead
#   ts.resample('ME', kind='period').mean()
# 2000-01   -0.201488
# 2000-02   -0.104592
# 2000-03    0.015601
# 2000-04   -0.176555
# Freq: M, dtype: float64

# %% [markdown]
# Периоды часто нужны для корректной визуализации, что бы результат на графике отражался не на последнее число, а на квартал.

# %%
tss = ts.resample('M').mean()
plt.figure(figsize=(10,7))
plt.bar(tss.index, tss.values);
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/1312340492.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tss = ts.resample('M').mean()

# %%
### Здесь ошибка, важно понять почему она возникает
tss = ts.resample('M',kind='period').mean()
display(tss)
plt.bar(tss.index, tss.values)
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/921665490.py:2: FutureWarning: The 'kind' keyword in Series.resample is deprecated and will be removed in a future version. Explicitly cast the index to the desired type instead
#   tss = ts.resample('M',kind='period').mean()
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/921665490.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   tss = ts.resample('M',kind='period').mean()
# 2000-01   -0.201488
# 2000-02   -0.104592
# 2000-03    0.015601
# 2000-04   -0.176555
# Freq: M, dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2613, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2612 try:
# -> 2613     left = x - width / 2
#    2614 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'Period' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[232], line 4
#       2 tss = ts.resample('M',kind='period').mean()
#       3 display(tss)
# ----> 4 plt.bar(tss.index, tss.values)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_axes.py:2615, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2613         left = x - width / 2
#    2614     except TypeError as e:
# -> 2615         raise TypeError(f'the dtypes of parameters x ({x.dtype}) '
#    2616                         f'and width ({width.dtype}) '
#    2617                         f'are incompatible') from e
#    2618     bottom = y
#    2619 else:  # horizontal
#
# TypeError: the dtypes of parameters x (object) and width (float64) are incompatible

# %%
plt.bar(tss.index.strftime('%m-%Y'), tss.values);

# %%
tss = ts.resample('ME',kind='period').mean()
rs = tss.reset_index()
display(rs)
sns.barplot(x='index',  y=0 , data = rs)
plt.show()
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_65125/2205038140.py:1: FutureWarning: The 'kind' keyword in Series.resample is deprecated and will be removed in a future version. Explicitly cast the index to the desired type instead
#   tss = ts.resample('ME',kind='period').mean()
#      index         0
# 0  2000-01 -0.201488
# 1  2000-02 -0.104592
# 2  2000-03  0.015601
# 3  2000-04 -0.176555

# %% [markdown]
# ### Регуляризация частоты

# %%
rng = pd.date_range('2000-01-01', periods=12, freq='min')
ts = pd.Series(np.arange(12), index=rng)
ts
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:01:00     1
# 2000-01-01 00:02:00     2
# 2000-01-01 00:03:00     3
# 2000-01-01 00:04:00     4
# 2000-01-01 00:05:00     5
# 2000-01-01 00:06:00     6
# 2000-01-01 00:07:00     7
# 2000-01-01 00:08:00     8
# 2000-01-01 00:09:00     9
# 2000-01-01 00:10:00    10
# 2000-01-01 00:11:00    11
# Freq: min, dtype: int64

# %%
ts.resample('5min').sum()
# Out:
# 2000-01-01 00:00:00    10
# 2000-01-01 00:05:00    35
# 2000-01-01 00:10:00    21
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='right').sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='left').sum()
# Out:
# 2000-01-01 00:00:00    10
# 2000-01-01 00:05:00    35
# 2000-01-01 00:10:00    21
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='left', label='right').sum()
# Out:
# 2000-01-01 00:05:00    10
# 2000-01-01 00:10:00    35
# 2000-01-01 00:15:00    21
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='right').sum()
# Out:
# 1999-12-31 23:55:00     0
# 2000-01-01 00:00:00    15
# 2000-01-01 00:05:00    40
# 2000-01-01 00:10:00    11
# Freq: 5min, dtype: int64

# %%
ts.resample('5min', closed='right', label='right').sum()
# Out:
# 2000-01-01 00:00:00     0
# 2000-01-01 00:05:00    15
# 2000-01-01 00:10:00    40
# 2000-01-01 00:15:00    11
# Freq: 5min, dtype: int64

# %% [markdown]
# Влючение окончания и меток интервалов
#
# [<img src="resample.pdf" width="750"/>](resample.pdf)

# %% [markdown]
# #### Как на бирже (ohlc)

# %%
ts.resample('5min').ohlc()
# Out:
#                      open  high  low  close
# 2000-01-01 00:00:00     0     4    0      4
# 2000-01-01 00:05:00     5     9    5      9
# 2000-01-01 00:10:00    10    11   10     11

# %% [markdown]
# ### Интерполяция

# %%
frame = pd.DataFrame(np.random.randn(2, 4),
                     index=pd.date_range('12/01/2020', periods=2,
                                         freq='W-WED'),
                     columns=['Colorado', 'Texas', 'New York', 'Ohio'])
frame
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547

# %%
# заполним пропуски
df_daily = frame.resample('D').asfreq()
df_daily
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-03       NaN       NaN       NaN       NaN
# 2020-12-04       NaN       NaN       NaN       NaN
# 2020-12-05       NaN       NaN       NaN       NaN
# 2020-12-06       NaN       NaN       NaN       NaN
# 2020-12-07       NaN       NaN       NaN       NaN
# 2020-12-08       NaN       NaN       NaN       NaN
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547

# %%
frame.resample('D').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-03   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-04   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-05   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-06   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-07   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-08   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547

# %%
frame.resample('D').ffill(limit=2)
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-03   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-04   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-05       NaN       NaN       NaN       NaN
# 2020-12-06       NaN       NaN       NaN       NaN
# 2020-12-07       NaN       NaN       NaN       NaN
# 2020-12-08       NaN       NaN       NaN       NaN
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547

# %%
display(frame)
frame.resample('W-THU').ffill()
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547
#             Colorado     Texas  New York      Ohio
# 2020-12-03   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-10   0.06023  2.463242 -0.192361  0.301547

# %%
# настоящая интерполяция
display(df_daily)
inter = df_daily.interpolate(method='linear', axis=0)
display(inter)
sns.lineplot(data = inter.Colorado);
# Out:
#             Colorado     Texas  New York      Ohio
# 2020-12-02   0.25755 -0.074446 -1.918771 -0.026514
# 2020-12-03       NaN       NaN       NaN       NaN
# 2020-12-04       NaN       NaN       NaN       NaN
# 2020-12-05       NaN       NaN       NaN       NaN
# 2020-12-06       NaN       NaN       NaN       NaN
# 2020-12-07       NaN       NaN       NaN       NaN
# 2020-12-08       NaN       NaN       NaN       NaN
# 2020-12-09   0.06023  2.463242 -0.192361  0.301547
#             Colorado     Texas  New York      Ohio
# 2020-12-02  0.257550 -0.074446 -1.918771 -0.026514
# 2020-12-03  0.229362  0.288081 -1.672141  0.020352
# 2020-12-04  0.201173  0.650608 -1.425511  0.067218
# 2020-12-05  0.172985  1.013135 -1.178881  0.114084
# 2020-12-06  0.144796  1.375662 -0.932251  0.160950
# 2020-12-07  0.116607  1.738188 -0.685621  0.207816
# 2020-12-08  0.088419  2.100715 -0.438991  0.254681
# 2020-12-09  0.060230  2.463242 -0.192361  0.301547

# %% [markdown]
# ## Скользящие окна

# %%
close_px_all = pd.read_csv('stock_px_2.csv',
                           parse_dates=True, 
                           index_col=0)
close_px_all
# Out:
#               AAPL   MSFT    XOM      SPX
# 2003-01-02    7.40  21.11  29.22   909.03
# 2003-01-03    7.45  21.14  29.24   908.59
# 2003-01-06    7.45  21.52  29.96   929.01
# 2003-01-07    7.43  21.93  28.95   922.93
# 2003-01-08    7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]
close_px = close_px.resample('B').ffill()
close_px
# Out:
#               AAPL   MSFT    XOM
# 2003-01-02    7.40  21.11  29.22
# 2003-01-03    7.45  21.14  29.24
# 2003-01-06    7.45  21.52  29.96
# 2003-01-07    7.43  21.93  28.95
# 2003-01-08    7.28  21.31  28.83
# ...            ...    ...    ...
# 2011-10-10  388.81  26.94  76.28
# 2011-10-11  400.29  27.00  76.27
# 2011-10-12  402.19  26.96  77.16
# 2011-10-13  408.43  27.18  76.37
# 2011-10-14  422.00  27.27  78.11
#
# [2292 rows x 3 columns]

# %%
close_px.AAPL.plot();
close_px.AAPL.rolling(250).mean().plot();

# %%
close_px.AAPL.rolling(250).mean()[:10]
# Out:
# 2003-01-02   NaN
# 2003-01-03   NaN
# 2003-01-06   NaN
# 2003-01-07   NaN
# 2003-01-08   NaN
# 2003-01-09   NaN
# 2003-01-10   NaN
# 2003-01-13   NaN
# 2003-01-14   NaN
# 2003-01-15   NaN
# Freq: B, Name: AAPL, dtype: float64

# %%
close_px.AAPL.rolling(250, min_periods=0).mean()[:10]
# Out:
# 2003-01-02    7.400000
# 2003-01-03    7.425000
# 2003-01-06    7.433333
# 2003-01-07    7.432500
# 2003-01-08    7.402000
# 2003-01-09    7.391667
# 2003-01-10    7.387143
# 2003-01-13    7.378750
# 2003-01-14    7.370000
# 2003-01-15    7.355000
# Freq: B, Name: AAPL, dtype: float64

# %%
close_px.AAPL[:10]
# Out:
# 2003-01-02    7.40
# 2003-01-03    7.45
# 2003-01-06    7.45
# 2003-01-07    7.43
# 2003-01-08    7.28
# 2003-01-09    7.34
# 2003-01-10    7.36
# 2003-01-13    7.32
# 2003-01-14    7.30
# 2003-01-15    7.22
# Freq: B, Name: AAPL, dtype: float64

# %%
appl_std250 = close_px.AAPL.rolling(250, min_periods=0).std()
appl_std250.plot();

# %%
close_px.rolling(60).mean().plot(logy=True); # лог. масштаб

# %%
# 20 ДНЕВНОЕ скользящее среднее
close_px.rolling('20D').mean()
# Out:
#                   AAPL       MSFT        XOM
# 2003-01-02    7.400000  21.110000  29.220000
# 2003-01-03    7.425000  21.125000  29.230000
# 2003-01-06    7.433333  21.256667  29.473333
# 2003-01-07    7.432500  21.425000  29.342500
# 2003-01-08    7.402000  21.402000  29.240000
# ...                ...        ...        ...
# 2011-10-10  389.351429  25.602143  72.527857
# 2011-10-11  388.505000  25.674286  72.835000
# 2011-10-12  388.531429  25.810000  73.400714
# 2011-10-13  388.826429  25.961429  73.905000
# 2011-10-14  391.038000  26.048667  74.185333
#
# [2292 rows x 3 columns]

# %%
# Скользящие с затуханием

aapl_px = close_px.AAPL['2006':'2007']

ma60 = aapl_px.rolling(30, min_periods=0).mean()
ewma60 = aapl_px.ewm(span=10).mean() # придаем больший вес поздним значениям


plt.figure(figsize=(10,7))
aapl_px.plot( label='AAPL')
ma60.plot( label='Simple MA');
ewma60.plot( label='EW MA');
plt.legend();
