# %%
import numpy as np
import pandas as pd
import yfinance as yf

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import datetime

print(pd.__version__)
print(sns.__version__)
print(yf.__version__)
# Out:
# 2.2.3
# 0.13.2
# 1.3.0

# %%
# start = datetime.datetime(2015, 1, 1)
# end = datetime.datetime(2020, 12, 31)

symbol=['NKE','MSFT','AAPL','CVX','IBM','AXP']

# %%
df = yf.download( symbol, start='2008-1-1', end='2009-12-31')
df
# Out:
# [*********************100%***********************]  6 of 6 completed
# Price          Close                                                         \
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.837991  38.495186  45.596645  55.192333  25.194561  12.325454
# 2008-01-03  5.840688  38.020016  46.157700  55.303028  25.301859  12.214433
# 2008-01-04  5.394839  37.062172  45.542988  53.315498  24.593670  12.025498
# 2008-01-07  5.322628  37.228096  44.947781  52.746136  24.758202  12.097567
# 2008-01-08  5.131164  36.164658  44.372093  51.449219  23.928392  12.043032
# ...              ...        ...        ...        ...        ...        ...
# 2009-12-23  6.055524  32.610428  40.211102  71.127800  23.055010  13.197040
# 2009-12-24  6.263466  32.982361  40.414665  71.439713  23.114664  13.158721
# 2009-12-28  6.340474  32.483818  40.592140  72.391724  23.241426  13.209134
# 2009-12-29  6.265264  32.349285  40.299858  72.140045  23.405457  13.352321
# 2009-12-30  6.341370  32.285980  40.529507  72.533958  23.084831  13.338204
#
# Price           High                                   ...       Open  \
# Ticker          AAPL        AXP        CVX        IBM  ...        CVX
# Date                                                   ...
# 2008-01-02  6.000391  39.460581  46.196731  57.459281  ...  45.840582
# 2008-01-03  5.914397  38.842111  46.269908  55.656254  ...  45.762523
# 2008-01-04  5.782860  37.703257  46.450433  54.802195  ...  45.801560
# 2008-01-07  5.501208  37.786214  45.733257  53.246976  ...  45.733257
# 2008-01-08  5.467050  37.484536  45.557626  52.920101  ...  45.084392
# ...              ...        ...        ...        ...  ...        ...
# 2009-12-23  6.063914  33.108962  40.675638  71.127800  ...  40.644322
# 2009-12-24  6.272756  32.998188  40.451202  71.439713  ...  40.200663
# 2009-12-28  6.410587  33.069399  40.659996  72.391724  ...  40.597361
# 2009-12-29  6.373731  32.642074  40.680884  72.424556  ...  40.613028
# 2009-12-30  6.352157  32.309722  40.539944  72.594144  ...  40.242432
#
# Price                                            Volume                      \
# Ticker            IBM       MSFT        NKE        AAPL       AXP       CVX
# Date
# 2008-01-02  57.459281  25.602309  12.528021  1079178800   8053700   9058000
# 2008-01-03  55.266127  25.194558  12.325455   842066400   7753200  10479200
# 2008-01-04  54.802195  25.173100  12.122887  1455832000   8501400  13103800
# 2008-01-07  52.851577  24.715280  12.076141  2072193200  14031100  12892200
# 2008-01-08  52.746124  24.829730  12.154054  1523816000  11721000  10987700
# ...               ...        ...        ...         ...       ...       ...
# 2009-12-23  70.963660  22.898426  13.122423   345525600   5296400   7342600
# 2009-12-24  71.067656  23.025187  13.197038   500889200   2070000   2565500
# 2009-12-28  71.669504  23.114669  13.158718   644565600   5369900   4192800
# 2009-12-29  72.375313  23.375632  13.209138   445205600   4438200   4810600
# 2009-12-30  71.800797  23.226502  13.279721   412084400   3557100   4300800
#
# Price
# Ticker           IBM      MSFT       NKE
# Date
# 2008-01-02   9940661  63004200   9781600
# 2008-01-03   7875229  49599600  10636000
# 2008-01-04  11542192  72090800  22335200
# 2008-01-07  13232318  80164300  20808400
# 2008-01-08   9868382  79148300  16714400
# ...              ...       ...       ...
# 2009-12-23   4317470  28362700   6148400
# 2009-12-24   4461295  11083900   2302000
# 2009-12-28   6067218  25384000   5648000
# 2009-12-29   4376673  29716200   8083200
# 2009-12-30   4044882  42006200   6932000
#
# [504 rows x 30 columns]

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',  'AXP'),
#             ( 'Close',  'CVX'),
#             ( 'Close',  'IBM'),
#             ( 'Close', 'MSFT'),
#             ( 'Close',  'NKE'),
#             (  'High', 'AAPL'),
#             (  'High',  'AXP'),
#             (  'High',  'CVX'),
#             (  'High',  'IBM'),
#             (  'High', 'MSFT'),
#             (  'High',  'NKE'),
#             (   'Low', 'AAPL'),
#             (   'Low',  'AXP'),
#             (   'Low',  'CVX'),
#             (   'Low',  'IBM'),
#             (   'Low', 'MSFT'),
#             (   'Low',  'NKE'),
#             (  'Open', 'AAPL'),
#             (  'Open',  'AXP'),
#             (  'Open',  'CVX'),
#             (  'Open',  'IBM'),
#             (  'Open', 'MSFT'),
#             (  'Open',  'NKE'),
#             ('Volume', 'AAPL'),
#             ('Volume',  'AXP'),
#             ('Volume',  'CVX'),
#             ('Volume',  'IBM'),
#             ('Volume', 'MSFT'),
#             ('Volume',  'NKE')],
#            names=['Price', 'Ticker'])

# %%
df['Open']
# Out:
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.970728  39.287112  45.840582  57.459281  25.602309  12.528021
# 2008-01-03  5.855070  38.615847  45.762523  55.266127  25.194558  12.325455
# 2008-01-04  5.736417  37.703257  45.801560  54.802195  25.173100  12.122887
# 2008-01-07  5.430795  37.356311  45.733257  52.851577  24.715280  12.076141
# 2008-01-08  5.397535  37.484536  45.084392  52.746124  24.829730  12.154054
# ...              ...        ...        ...        ...        ...        ...
# 2009-12-23  6.028557  32.919043  40.644322  70.963660  22.898426  13.122423
# 2009-12-24  6.098970  32.721223  40.200663  71.067656  23.025187  13.197038
# 2009-12-28  6.343771  32.990264  40.597361  71.669504  23.114669  13.158718
# 2009-12-29  6.371034  32.452155  40.613028  72.375313  23.375632  13.209138
# 2009-12-30  6.257174  32.127715  40.242432  71.800797  23.226502  13.279721
#
# [504 rows x 6 columns]

# %%
stoks_close = df['Close']
stoks_close.head(5)
# Out:
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.837991  38.495186  45.596645  55.192333  25.194561  12.325454
# 2008-01-03  5.840688  38.020016  46.157700  55.303028  25.301859  12.214433
# 2008-01-04  5.394839  37.062172  45.542988  53.315498  24.593670  12.025498
# 2008-01-07  5.322628  37.228096  44.947781  52.746136  24.758202  12.097567
# 2008-01-08  5.131164  36.164658  44.372093  51.449219  23.928392  12.043032

# %%
stoks_volume = df['Volume']
stoks_volume.head(5)
# Out:
# Ticker            AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  1079178800   8053700   9058000   9940661  63004200   9781600
# 2008-01-03   842066400   7753200  10479200   7875229  49599600  10636000
# 2008-01-04  1455832000   8501400  13103800  11542192  72090800  22335200
# 2008-01-07  2072193200  14031100  12892200  13232318  80164300  20808400
# 2008-01-08  1523816000  11721000  10987700   9868382  79148300  16714400

# %%
stoks_close.plot();

# %%
stoks_close['AAPL'].plot();

# %%
plt.bar(stoks_volume['AAPL'].index,stoks_volume['AAPL'].values, color ='b');

# %%
# Здесь разбираемся сами и совмещаем два графика

# %% [markdown]
# ### Вычисляем ежедневное процентное закрытие
# $$ r_t =\dfrac{p_t}{p_{t-1}}-1 $$

# %%
daily_pct_na=(stoks_close/stoks_close.shift(1)-1)
daily_pct_na.head()
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03  0.000462 -0.012344  0.012305  0.002006  0.004259 -0.009007
# 2008-01-04 -0.076335 -0.025193 -0.013318 -0.035939 -0.027990 -0.015468
# 2008-01-07 -0.013385  0.004477 -0.013069 -0.010679  0.006690  0.005993
# 2008-01-08 -0.035972 -0.028565 -0.012808 -0.024588 -0.033517 -0.004508

# %%
#тут внимательнее с данными
daily_pct_0=(stoks_close/stoks_close.shift(1)-1).fillna(0)
daily_pct_0.head()
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2008-01-03  0.000462 -0.012344  0.012305  0.002006  0.004259 -0.009007
# 2008-01-04 -0.076335 -0.025193 -0.013318 -0.035939 -0.027990 -0.015468
# 2008-01-07 -0.013385  0.004477 -0.013069 -0.010679  0.006690  0.005993
# 2008-01-08 -0.035972 -0.028565 -0.012808 -0.024588 -0.033517 -0.004508

# %% [markdown]
# ### Вычисляем кумулятивную процентную доходность
# $$ i_0=r_0=0 $$
# $$ i_t=(i_{t-1}+r_t)100 $$

# %%
daily_sum_na=(daily_pct_na*100).cumsum()
daily_sum_na.head(5)
# Out:
# Ticker           AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02        NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03   0.046189 -1.234362  1.230473  0.200562  0.425877 -0.900746
# 2008-01-04  -7.587312 -3.753677 -0.101292 -3.393327 -2.373083 -2.447558
# 2008-01-07  -8.925819 -3.305986 -1.408205 -4.461240 -1.704083 -1.848263
# 2008-01-08 -12.522997 -6.162534 -2.688996 -6.920030 -5.055737 -2.299056

# %%
daily_sum_0=(daily_pct_0*100).cumsum()
daily_sum_0.head(5)
# Out:
# Ticker           AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2008-01-03   0.046189 -1.234362  1.230473  0.200562  0.425877 -0.900746
# 2008-01-04  -7.587312 -3.753677 -0.101292 -3.393327 -2.373083 -2.447558
# 2008-01-07  -8.925819 -3.305986 -1.408205 -4.461240 -1.704083 -1.848263
# 2008-01-08 -12.522997 -6.162534 -2.688996 -6.920030 -5.055737 -2.299056

# %%
daily_sum_0.plot();

# %% [markdown]
# ### Вычисляем накопленную процентную доходность
# $$ i_0 = 1 $$
# $$ i_t = (1+r_t) i_{t-1} $$

# %%
daily_prod_na=(1 + daily_pct_na).cumprod()
daily_prod_na.head(5)
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03  1.000462  0.987656  1.012305  1.002006  1.004259  0.990993
# 2008-01-04  0.924092  0.962774  0.998823  0.965995  0.976150  0.975664
# 2008-01-07  0.911723  0.967084  0.985769  0.955679  0.982680  0.981511
# 2008-01-08  0.878926  0.939459  0.973144  0.932181  0.949744  0.977086

# %%
daily_prod_0=(1 + daily_pct_0).cumprod()
daily_prod_0.head(5)
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2008-01-03  1.000462  0.987656  1.012305  1.002006  1.004259  0.990993
# 2008-01-04  0.924092  0.962774  0.998823  0.965995  0.976150  0.975664
# 2008-01-07  0.911723  0.967084  0.985769  0.955679  0.982680  0.981511
# 2008-01-08  0.878926  0.939459  0.973144  0.932181  0.949744  0.977086

# %%
daily_prod_0.plot();

# %%
daily_prod_0.asfreq(freq='ME')
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-31  0.694724  0.962579  0.890756  1.023116  0.925610  0.969185
# 2008-02-29  0.641655  0.828762  0.933919  1.091750  0.775289  0.951328
# 2008-03-31  0.736502  0.856584  0.919909  1.104023  0.808923  1.078668
# 2008-04-30  0.892784  0.944489  1.036191  1.157336  0.812913  1.059634
# 2008-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-06-30  0.859372  0.740918  1.075460  1.141174  0.787012  0.948792
# 2008-07-31  0.815798  0.733277  0.917390  1.232157  0.735803  0.933990
# 2008-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-09-30  0.583351  0.699893  0.901592  1.130445  0.766598  1.068796
# 2008-10-31  0.552197  0.546016  0.815456  0.898576  0.641369  0.920698
# 2008-11-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-12-31  0.438052  0.368312  0.815572  0.817972  0.562144  0.818712
# 2009-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2009-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2009-03-31  0.539520  0.272957  0.748193  0.946822  0.534845  0.757182
# 2009-04-30  0.645812  0.511820  0.735508  1.008581  0.589873  0.847289
# 2009-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2009-06-30  0.731010  0.475201  0.744308  1.025736  0.696462  0.839755
# 2009-07-31  0.838586  0.579279  0.780484  1.158447  0.689137  0.918574
# 2009-08-31  0.863324  0.691536  0.793628  1.165034  0.726308  0.898302
# 2009-09-30  0.951294  0.696863  0.799188  1.180430  0.757835  1.054233
# 2009-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 
# 2009-06-01  0.715202  0.527446  0.777563  1.064537  0.627021  0.956934
# 2009-07-01  0.733063  0.470294  0.747341  1.029862  0.704374  0.850135
# 2009-08-01  0.854188  0.585822  0.790932  1.177995  0.698220  0.918250
# 2009-09-01  0.848389  0.653913  0.777061  1.151612  0.707156  0.881597
# 2009-10-01  0.928249  0.667261  0.780805  1.163554  0.733084  1.018385
# 2009-11-01  0.971618  0.733453  0.869655  1.189805  0.821479  1.018385
# 2009-12-01  1.010932  0.848980  0.905011  1.268305  0.888147  1.065639

# %%
month_prod.plot();

# %% [markdown]
# ### Скользящее среднее

# %%
aapl_close=stoks_close['IBM']
ma_30=aapl_close.rolling(30).mean()
ma_90=aapl_close.rolling(90).mean()
result=pd.concat([aapl_close,ma_30,ma_90],axis=1)
result.columns=['IBM','ma_30','ma_90']
result.plot();

# %%
aapl_close=daily_sum_0['AAPL']
msft_close=daily_sum_0['MSFT']

# %%
plt.scatter(aapl_close,aapl_close);

# %%
plt.scatter(aapl_close,msft_close);

# %%
df=pd.concat([aapl_close,msft_close],axis=1)
sns.scatterplot(x="AAPL", y="MSFT",data=df);

# %%
sns.residplot( x = aapl_close, y = msft_close, lowess=True, color="g");

# %%
sns.jointplot(x="AAPL", y="MSFT", data=df, kind="reg", color="m", height=7);

# %% [markdown]
# ### Волатильность

# %%
per=30

vol=daily_pct_0.rolling(per).std()*np.sqrt(per)
vol.plot();

# %% [markdown]
# ### Оценим риск

# %%
df_risk=pd.concat([daily_pct_0.mean(),daily_pct_0.std()],axis=1)
df_risk.columns=["mean",'std']
df_risk
# Out:
#             mean       std
# Ticker
# AAPL    0.000622  0.030187
# AXP     0.000728  0.046675
# CVX     0.000150  0.027852
# IBM     0.000747  0.020285
# MSFT    0.000195  0.027289
# NKE     0.000526  0.027283

# %%
sns.scatterplot(x="mean", y="std",data=df_risk,hue=df_risk.index)
# Out:
# <Axes: xlabel='mean', ylabel='std'>

# %% [markdown]
# ### Взаимная корреляция
#
# напомним про клику и диверсификацию портфеля

# %%
corr=daily_pct_0.corr()
corr
# Out:
# Ticker      AAPL       AXP       CVX       IBM      MSFT       NKE
# Ticker
# AAPL    1.000000  0.548966  0.533640  0.587965  0.555598  0.511043
# AXP     0.548966  1.000000  0.586455  0.578018  0.593985  0.596010
# CVX     0.533640  0.586455  1.000000  0.627704  0.647863  0.542539
# IBM     0.587965  0.578018  0.627704  1.000000  0.618611  0.625597
# MSFT    0.555598  0.593985  0.647863  0.618611  1.000000  0.532698
# NKE     0.511043  0.596010  0.542539  0.625597  0.532698  1.000000

# %%
sns.heatmap(corr, annot=True);

# %%
from matplotlib import cm
cmap = cm.coolwarm
#np.fill_diagonal(corr.values, np.nan)
np.fill_diagonal(corr.values, 0)
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap=cmap);
